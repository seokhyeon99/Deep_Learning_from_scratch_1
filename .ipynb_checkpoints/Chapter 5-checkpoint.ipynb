# %% [markdown]
# # Chapter 5. Backpropagation

# %% [markdown]
# ## 5.1 calculation graph

# %%
from IPython.display import Image
Image("calculation graph.png")

# %% [markdown]
#                                         forward propagation
#         ==========================================================================================>
#         <==========================================================================================
#                                         backward propagation

# %% [markdown]
# Calculation of each node is localized. Therefore, each node dosn't have to care other calculations than its own calculation.
# By using calculation graph, we can efficiently calculate the differentiation by backpropagation.

# %% [markdown]
# ## 5.2 chain rule

# %% [markdown]
# $$ \frac{\partial z}{\partial x} = \frac{\partial z}{\partial t} \frac{\partial t}{\partial x} $$

# %% [markdown]
# i.e. $$z = t^2$$  $$t = x+y $$

# %% [markdown]
# $$ \frac{\partial z}{\partial t} = 2t $$
# $$ \frac{\partial t}{\partial x} = 1 $$
# $$ \frac{\partial z}{\partial x} = 2t*1 = 2(x+y) $$

# %% [markdown]
# ## 5.3 backpropagation

# %% [markdown]
# - backpropagation of addition node

# %%
from IPython.display import Image
Image("backpropagation of addition.png")

# %% [markdown]
#     backpropagation of addition is only multiplying the input by 1 and just transmitting the input value to the next node.
#     i.e.
# $$ z=x+y $$
# $$\frac{\partial z}{\partial x} = 1 $$
# $$\frac{\partial z}{\partial y} = 1 $$

# %% [markdown]
# - backpropagation of multiplication node

# %%
from IPython.display import Image
Image("backpropagation of multiplication.png")

# %% [markdown]
#     backpropagation of multiplication is multiplying the input by the other value and transmitting the result to the next node.
#     i.e.
# $$ z = xy$$
# $$ \frac{\partial z}{\partial x} = y$$
# $$ \frac{\partial z}{\partial y} = x$$

# %% [markdown]
#     Therefore, backpropagation of multiplication needs the input value in forward propagation.

# %% [markdown]
# ## 5.4 implement simple layers

# %%
class MulLayer: #multiplication layer
    def __init__(self):
        self.x = None
        self.y = None
    def forward(self, x, y):
        self.x = x
        self.y = y
        out = x * y
        return out
    def backward(self, dout):
        dx = dout * self.y
        dy = dout * self.x
        return dx, dy

# %%
#forward-propagation
apple = 100
apple_num = 2
tax = 1.1

mul_apple_layer = MulLayer()
mul_tax_layer = MulLayer()

apple_price = mul_apple_layer.forward(apple, apple_num)
price = mul_tax_layer.forward(apple_price, tax)
print(price)
# Out:
# 220.00000000000003

# %%
#backpropagation
dprice = 1
dapple_price, dtax = mul_tax_layer.backward(dprice)
dapple, dapple_num = mul_apple_layer.backward(dapple_price)
print(dapple, dapple_num, dtax)
# Out:
# 2.2 110.00000000000001 200

# %%
class AddLayer: #Addition layer
    def __init__(self):
        pass
    def forward(self, x, y):
        return x+y
    def backward(self, dout):
        dx = dout
        dy = dout
        return dx, dy

# %%
apple = 100
apple_num = 2
orange = 150
orange_num = 3
tax = 1.1

mul_apple_layer = MulLayer()
mul_orange_layer = MulLayer()
add_apple_orange_layer = AddLayer()
mul_tax_layer = MulLayer()

apple_price = mul_apple_layer.forward(apple, apple_num)
orange_price = mul_orange_layer.forward(orange, orange_num)
all_price = add_apple_orange_layer.forward(apple_price, orange_price)
price = mul_tax_layer.forward(all_price, tax)

dprice = 1
dall_price, dtax = mul_tax_layer.backward(dprice)
dapple_priced, dorange_price = add_apple_orange_layer.backward(dall_price)
dapple, dapple_num = mul_apple_layer.backward(dapple_price)
dorange, dorange_num = mul_orange_layer.backward(dorange_price)

print(price)
print(dapple_num, dapple, dorange_num, dorange, dtax)
# Out:
# 715.0000000000001
# 110.00000000000001 2.2 165.0 3.3000000000000003 650

# %% [markdown]
# ## 5.5 implement activation function

# %% [markdown]
# - Relu
#
#     $y =$
# $\left[\begin{array}{ccc}
# x & (x>0)\\
# 0 & (x\leq0)
# \end{array}\right]$
#
#     $\frac{\partial y}{\partial x} =$
# $\left[\begin{array}{ccc}
# 1 & (x>0)\\
# 0 & (x\leq0)
# \end{array}\right]$

# %%
class Relu:
    def __init__(self):
        self.mask = None
    def forward(self, x):
        self.mask = (x<=0)
        out = x.copy()
        out[self.mask] = 0
        return out
    def backward(self, dout):
        dout[self.mask] = 0
        return dout

# %% [markdown]
# - Sigmoid
#
#     $ y = \frac{1}{1+exp(-x)} $
#
#     $ \frac {\partial y}{\partial x} = (\frac{1}{1+e^{-x}})^2 e^{-x} = \frac{1}{1+e^{-x}} * \frac{e^{-x}}{1+e^{-x}} = y(1-y)$

# %%
import numpy as np
class Sigmoid:
    def __init__(self):
        self.out = None
    def forward(self, x):
        out = 1/(1+np.exp(-x))
        self.out = out
        return out
    def backward(self, dout):
        dx = dout*self.out*(1-self.out)
        return dx

# %% [markdown]
# ## 5.6 implement Affine/Softmax layers

# %% [markdown]
# - Affine
#
#     $ Y = X \cdot W + B $
#
#     $ \frac{\partial L}{\partial Y} \frac{\partial Y}{\partial X} = \frac{\partial L}{\partial Y} \cdot W $
#     $ \frac{\partial L}{\partial X} = \frac{\partial L}{\partial Y} \cdot W^T $
#
#     $ \frac{\partial L}{\partial Y} \frac{\partial Y}{\partial W} = X \cdot \frac{\partial L}{\partial Y} $
#     $ \frac{\partial L}{\partial W} = X^T \cdot \frac{\partial L}{\partial Y} $

# %%
class Affine:
    def __init__(self, W, b):
        self.W = W
        self.b = b
        self.x = None
        self.dW = None
        self.db = None
    def forward(self, x):
        self.x = x
        out = np.dot(x, self.W) + self.b    
        return out
    def backward(self, dout):
        dx = np.dot(dout, self.W.T)
        self.dW = np.dot(self.x.T, dout)
        self.db = np.sum(dout, axis=0)
        return dx

# %% [markdown]
# - Softmax with loss
#     Softmax layer sent the outputs by normalizing the inputs (sum of every output should be 1)

# %%
from IPython.display import Image
Image("softmax-with-loss calculation graph.png") #appendix A

# %%
from IPython.display import Image
Image("simplified softmax-with-loss calculation graph.png")

# %%
from functions import softmax, cross_entropy_error
class SoftmaxWithLoss:
    def __init__(self):
        self.loss = None
        self.y = None
        self.t = None
    def forward(self, x, t):
        self.y = softmax(x)
        self.t = t
        self.loss = cross_entropy_error(self.y, self.t)
        return self.loss
    def backward(self, dout):
        batch_size = self.t.shape[0]
        dx = (self.y - self.t)/batch_size
        return dx

# %% [markdown]
# ## 5.7 implement backpropagation

# %%
import numpy as np
from gradient import numerical_gradient
from collections import OrderedDict

class TwoLayerNet:
    def __init__(self, input_size, hidden_size, output_size, weight_init_std=0.01):
        #initiate weights
        self.params ={}
        self.params['W1'] = weight_init_std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size)
        self.params['W2'] = weight_init_std * np.random.randn(hidden_size, output_size)
        self.params['b2'] = np.zeros(output_size)
        #initiate layers
        self.layers = OrderedDict()
        self.layers['Affine1'] = Affine(self.params['W1'], self.params['b1'])
        self.layers['Relu1'] = Relu()
        self.layers['Affine2'] = Affine(self.params['W2'], self.params['b2'])
        self.lastLayer = SoftmaxWithLoss()
    
    def predict(self, x):
        for layer in self.layers.values():#?
            x = layer.forward(x)
        return x
    
    def loss(self, x, t): #x: input data, t:answer data
        y = self.predict(x)
        return cross_entropy_error(y, t)
    
    def accuracy(self, x, t):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        #t = np.argmax(t, axis=1)
        accuracy = np.sum(y == t)/float(x.shape[0])
        return accuracy
    
    def numerical_gradient(self, x, t):
        loss_W = lambda W: self.loss(x,t) #p138 ?
        
        grads = {}
        grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
        grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
        grads['W2'] = numerical_gradient(loss_W, self.params['W2'])
        grads['b2'] = numerical_gradient(loss_W, self.params['b2'])
        return grads
    
    def gradient(self, x, t):
        self.loss(x,t)
        dout = 1
        dout = self.lastLayer.backward(dout)
        
        layers = list(self.layers.values())
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)
            
        grads = {}
        grads['W1'] = self.layers['Affine1'].dW
        grads['b1'] = self.layers['Affine1'].db
        grads['W2'] = self.layers['Affine2'].dW
        grads['b2'] = self.layers['Affine2'].db
        return grads

# %%
import numpy as np
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784')

X = mnist['data']
T = mnist['target']

x_train = X[:60000]
t_train = T[:60000]
x_test = X[60000:]
t_test = T[60000:]

network = TwoLayerNet(input_size=784, hidden_size=50, output_size=10)

x_batch = x_train[:3]
t_batch = t_train[:3]
t_batch = np.array(list(map(int, t_batch)))

grad_numerical = network.numerical_gradient(x_batch, t_batch)
grad_backprop = network.gradient(x_batch, t_batch)

for key in grad_numerical.keys():
    diff = np.average(np.abs(grad_backprop[key] - grad_numerical[key]))
    print(key + ":" + str(diff))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-8ec0bf72804d> in <module>
#      18
#      19 grad_numerical = network.numerical_gradient(x_batch, t_batch)
# ---> 20 grad_backprop = network.gradient(x_batch, t_batch)
#      21
#      22 for key in grad_numerical.keys():
#
# <ipython-input-26-08edad55de02> in gradient(self, x, t)
#      47         self.loss(x,t)
#      48         dout = 1
# ---> 49         dout = self.lastLayer.backward(dout)
#      50
#      51         layers = list(self.layers.values())
#
# <ipython-input-7-a9e9f7149e29> in backward(self, dout)
#      11         return self.loss
#      12     def backward(self, dout):
# ---> 13         batch_size = self.t.shape[0]
#      14         dx = (self.y - self.t)/batch_size
#      15         return dx
#
# AttributeError: 'NoneType' object has no attribute 'shape'
