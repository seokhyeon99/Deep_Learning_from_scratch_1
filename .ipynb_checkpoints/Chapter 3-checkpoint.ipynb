# %% [markdown]
# # Chapter 3. Nerual Network

# %% [markdown]
# Perceptron can be used for making the complicated functions, but human should still set the proper weights.

# %% [markdown]
# ## 3.1 From perceptron to neural network

# %% [markdown]
# Perceptron can be expressed the following formulas
#
#
# $ y = 0 \ (w_1x_1 + w_2x_2 \leq \theta) \\
# \ \ = 1 \  (w_1x_1 + w_2x_2 > \theta) $
#
# $ y = h(b+w_1x_1+w_2x_2)  \\
# h(x) = 0(x \leq 0) \  or\ 1(x > 0) $  #step function

# %% [markdown]
# Nerual network has input, hidden, and output layer.
# Activation function decides if total sum of every input signal makes the activation. It is $h(x)$ in the above example.

# %%
from IPython.display import Image
Image("Activation function's processing procedure.png")

# %% [markdown]
# ## 3.2 Activation function

# %% [markdown]
# ### Step function
# $ h(x) = 0(x \leq 0) \  or\ 1(x > 0) $

# %%
def step_function(x): # only real number can be used as a input
    if x>0:
        return 1
    else:
        return 0

# %%
import numpy as np
def step_function_ary(x): # array can be used as a input 
    y = x > 0 # y = [False True True True] if x = np.array([0,1,2,3])
    return y.astype(np.int) #change bool type to int type #[0 1 1 1]

# %%
import numpy as np
import matplotlib.pylab as plt

x = np.arange(-5.0, 5.0, 0.1)
y = step_function_ary(x)
plt.plot(x,y)
plt.ylim(-0.5, 1.5)
plt.show()

# %% [markdown]
# ### Sigmoid function
# $ h(x) = \frac{1}{1+e^{-x}} $

# %%
import numpy as np
def sigmoid(x):
    return 1/(1+np.exp(-x)) # can return not only real number but also numpy array

# %%
import numpy as np
import matplotlib.pylab as plt

x = np.arange(-5.0, 5.0, 0.1)
y = sigmoid(x)
plt.plot(x,y)
plt.ylim(-0.1, 1.1)
plt.show()

# %% [markdown]
# * Difference between sigmoid and step function
#        Sigmoid function is soft curve and the value is changed continously.
#        However, the value of step function is changed at the point x=0.
# * Common features between sigmoid and step function
#        The output is always between 0 and 1. If the input is important, they return big value. If not, they return small value.
#        Both of them are nonlinear function.

# %% [markdown]
# Activation function in neural network should be nonlinear function. The reason is no matter how linear function have a lot of hidden layer, we can implement it by not using hidden layer.
#
# $ i.e.\  if\ h(x) = cx\ and\ y(x) = h(h(h(x))),\ then\ y(x) = c^3x $ (it is same as $y(x) = ax\ where\  a = c^3$)

# %% [markdown]
# ### ReLU function
# $h(x) = x (x>0)\  or\  0(x \leq 0)$

# %%
def relu(x):
    return np.maximum(0,x)

# %%
import numpy as np
import matplotlib.pylab as plt

x = np.arange(-5.0, 5.0 ,0.1)
y = relu(x)
plt.plot(x,y)
plt.ylim(-0.5, 6.0)
plt.show()

# %% [markdown]
# ## 3.3 calculation of multi-demensional array

# %% [markdown]
# ### 3.3.1 Multi-dimensional array

# %%
import numpy as np
A = np.array([1,2,3,4])
print(A)
print(np.ndim(A))
print(A.shape) #return tuple
print(A.shape[0])
# Out:
# [1 2 3 4]
# 1
# (4,)
# 4

# %%
B = np.array([[1,2],[3,4],[5,6]])
print(B)
print(np.ndim(B))
print(B.shape)
print(B.shape[0])
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# 2
# (3, 2)
# 3

# %% [markdown]
# ### 3.3.2 Inner-product(dot-product) of matrices

# %%
A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])
print(np.dot(A,B))
# Out:
# [[19 22]
#  [43 50]]

# %% [markdown]
# To multiply two matrices, the number of elements of corresponding dimension should be same.

# %% [markdown]
# ### 3.3.3 Inner-product(dot-product) of matrices in neural network

# %%
from IPython.display import Image
Image("innerproduct.png")

# %%
X = np.array([1,2])
W = np.array([[1,3,5],[2,4,6]])
Y = np.dot(X,W)
print('X',X)
print('W',W)
print('Y',Y)
# Out:
# X [1 2]
# W [[1 3 5]
#  [2 4 6]]
# Y [ 5 11 17]

# %% [markdown]
# ## 3.4 Implementation 3-layer neural network

# %%
from IPython.display import Image
Image("3-layer neural network.png")

# %% [markdown]
# $ a_1^{(1)} = w_{11}^{(1)}x_1\ +\ w_{12}^{(1)}x_2\ +\ b_1^{(1)} $

# %% [markdown]
# we can express same formula simply using inner-product of matrices
# $ A^{(1)}\ =\ XW^{(1)}\ +\ B^{(1)}\
# where\ A^{(1)} = (a_1^{(1)}\ a_2^{(1)}\ a_3^{(1)}),\
# X = (x_1\ x_2),\
# B^{(1)} = (b_1^{(1)}\ b_2^{(1)}\ b_3^{(1)}),\
# W^{(1)} = ( \begin{matrix}
#             w_{11}^{(1)}\ w_{21}^{(1)}\ w_{31}^{(1)}\\
#             w_{12}^{(1)}\ w_{22}^{(1)}\ w_{32}^{(1)}\\
#             \end{matrix})$

# %%
from IPython.display import Image
Image("from input to first floor.png")

# %%
from IPython.display import Image
Image("from first floor to second floor.png")

# %%
from IPython.display import Image
Image("from second floor to output layer.png")

# %%
def identity_function(x):
    return x

def init_network():
    network = {}
    network['W1'] = np.array([[0.1,0.3,0.5],[0.2,0.4,0.6]])
    network['b1'] = np.array([0.1, 0.2, 0.3])
    network['W2'] = np.array([[0.1,0.4],[0.2,0.5],[0.3,0.6]])
    network['b2'] = np.array([0.1, 0.2])
    network['W3'] = np.array([[0.1,0.3],[0.2,0.4]])
    network['b3'] = np.array([0.1, 0.2])
    
    return network

def forward(network, x): #forward propagation
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    
    a1 = np.dot(X,W1) + b1
    z1 = sigmoid(a1)
    a2 = np.dot(z1,W2) + b2
    z2 = sigmoid(a2)
    a3 = np.dot(z2,W3) + b3
    y = identity_function(a3)
    
    return y

network = init_network()
x = np.array([1.0,0.5])
y = forward(network, x)
print(y)
# Out:
# [0.32403126 0.71230655]

# %% [markdown]
# ## 3.5 Design output layer

# %% [markdown]
# Normally identity function is used for regression and softmax is used for classification as an activation function in output layer.

# %% [markdown]
# ### Softmax function

# %% [markdown]
# $ y_k = \frac{e^{a_k}}{\Sigma_{i=1}^n e^{a_i}} $

# %%
import numpy as np
def softmax(a):
    exp_a = np.exp(a)
    sum_exp_a = np.sum(exp_a)
    return exp_a/sum_exp_a

# %% [markdown]
# Softmax activation function can easily have overflow problem. To solve the problem, we follow the formula below.
# $ y_k = \frac{e^{a_k}}{\Sigma_{i=1}^n e^{a_i}} = \frac{Ce^{a_k}}{C\Sigma_{i=1}^n e^{a_i}} = \frac{e^{a_k+logC}}{\Sigma_{i=1}^n e^{a_i+logC}} = \frac{e^{a_k+C'}}{\Sigma_{i=1}^n e^{a_i+C'}} $
# It shows the result of softmax isn't change though any value is added or subtracted in exponential part. We usually use the maximum value of input signals as $ C' $.

# %%
import numpy as np
def softmax_not_overflow(a):
    c = np.max(a)
    exp_a = np.exp(a-c)
    sum_exp_a = np.sum(exp_a)
    return exp_a/sum_exp_a

# %% [markdown]
# The outputs of softmax are always between 0 and 1. The total of the outputs of softmax is always 1. Therefore, we can interpret it as a 'probability'.
# (We can skip softmax because it does not change the relationship between the big and small value.)
# The number of neurons in the output layer is usally set as the number of classes that should be classified.

# %% [markdown]
# ## 3.6 Recognition hand-written nunber
